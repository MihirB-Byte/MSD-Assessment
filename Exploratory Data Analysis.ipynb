# %%
#Exploratory Data Analysis

# %%
#Import the relevent modules

import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the data into a pandas dataframe

demographic_df = pd.read_csv("Demographic.csv")
event_df = pd.read_csv("Event.csv")
injury_df = pd.read_csv("Injury.csv")

demographic_df
# Out:
#      Employee Name Gender Relationship  \
# 0       Person 999      F        Staff
# 1       Person 998      F        Staff
# 2       Person 997      F        Staff
# 3       Person 995      F        Staff
# 4       Person 994      F        Staff
# ...            ...    ...          ...
# 1616   Person 1003      F        Staff
# 1617   Person 1002      F        Staff
# 1618   Person 1001      F        Staff
# 1619   Person 1000      F        Staff
# 1620      Person 1      F        Staff
#
#                                 Position Title  Age Band Ethnicity  \
# 0                                 Case Manager         3         E
# 1                  Regional Disability Advisor         6         A
# 2                         Capability Developer         2         B
# 3                                 Case Manager         4         A
# 4                                 Case Manager         2         G
# ...                                        ...       ...       ...
# ...

# %%
event_df
# Out:
#       Incident ID Incident Date              Site 1 Name Site 2 Name  \
# 0               5    20/05/2019  Client Service Delivery    Region P
# 1               9    21/05/2019  Client Service Delivery    Region H
# 2              11    22/05/2019  Client Service Delivery    Region L
# 3              12    23/05/2019  Client Service Delivery    Region H
# 4              16    28/05/2019  Client Service Delivery    Region L
# ...           ...           ...                      ...         ...
# 3071        10987    19/01/2021          National Office    Region O
# 3072        10990    18/01/2021  Client Service Delivery    Region H
# 3073        10800    11/01/2021  Client Service Delivery    Region P
# 3074        11001    19/01/2021  Client Service Delivery    Region H
# 3075        11003    19/01/2021  Client Service Delivery    Region G
#
#      Site 3 Name               Incident Work Area Name     Event Type Name  \
# ...

# %%
injury_df
# Out:
#       Incident ID          Injury       Name  \
# 0               5  Sprain /Strain  Ergonomic
# 1               9  Sprain /Strain  Ergonomic
# 2              11  Sprain /Strain  Ergonomic
# 3              12  Sprain /Strain   Physical
# 4              16  Sprain /Strain   Physical
# ...           ...             ...        ...
# 3219         2451  Sprain /Strain  Ergonomic
# 3220         2452   Bone Fracture   Physical
# 3221         2454   Scald or burn   Physical
# 3222         2456  Sprain /Strain  Ergonomic
# 3223         2457  Sprain /Strain  Ergonomic
#
#                                  Sub Category          Body Part  \
# 0                    Lifting / carrying loads          Shoulders
# 1                           Poor work posture               Back
# 2                                Keyboard use              Wrist
# 3     Trip / fall hazard (cords /chairs etc.)              Ankle
# 4                    Moving or falling object  Finger(s) / Thumb
# ...

# %%
demographic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1621 entries, 0 to 1620
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Employee Name   1621 non-null   object
#  1   Gender          1621 non-null   object
#  2   Relationship    1621 non-null   object
#  3   Position Title  1621 non-null   object
#  4   Age Band        1621 non-null   int64
#  5   Ethnicity       1621 non-null   object
#  6   Salary Range    1621 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 88.8+ KB

# %%
event_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3076 entries, 0 to 3075
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Incident ID                    3076 non-null   int64
#  1   Incident Date                  3076 non-null   object
#  2   Site 1 Name                    3076 non-null   object
#  3   Site 2 Name                    3002 non-null   object
#  4   Site 3 Name                    2418 non-null   object
#  5   Incident Work Area Name        3076 non-null   object
#  6   Event Type Name                3076 non-null   object
#  7   Person Employee Name           3076 non-null   object
#  8   Incident Categories Full Name  3076 non-null   object
#  9   Potential Consequence          3076 non-null   object
#  10  Action Taken                   3076 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 264.5+ KB

# %%
#We notice the data type for date is an object. This will need to be changed as a datetime data type. 
#This will be a part of data clensing phase.

# %%
injury_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3224 entries, 0 to 3223
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Incident ID          3224 non-null   int64
#  1   Injury               2592 non-null   object
#  2   Name                 3224 non-null   object
#  3   Sub Category         3221 non-null   object
#  4   Body Part            3071 non-null   object
#  5   Treatment of Injury  3224 non-null   object
#  6   Incident Status      3224 non-null   object
#  7   Investigation Type   3224 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 201.6+ KB

# %%
unique_injuries = injury_df['Injury'].unique()
unique_injuries
# Out:
# array(['Sprain /Strain', 'Allergic reaction or irritation',
#        'Bruising / Crushing', 'Scald or burn', 'Multiple injuries',
#        'Psychological distress', nan, 'Open wound ',
#        'Loss of consciousness', 'Puncture wound',
#        'Cut / Laceration / Graze', 'Spinal cord injury ',
#        'Electric shock', 'Exposure to infectious material',
#        'Hearing Loss (work related)', 'Unassigned', 'Dislocation',
#        'Loss of sight', 'Foreign Body', 'Bone Fracture',
#        'Poisoning or Toxic effects', 'Poisoning or Toxic Effects'],
#       dtype=object)

# %%
injury_counts = injury_df['Injury'].value_counts()
injury_counts
# Out:
# Sprain /Strain                     1932
# Bruising / Crushing                 195
# Unassigned                           89
# Cut / Laceration / Graze             86
# Psychological distress               60
# Multiple injuries                    47
# Scald or burn                        44
# Allergic reaction or irritation      43
# Bone Fracture                        18
# Spinal cord injury                   16
# Puncture wound                       13
# Loss of consciousness                10
# Electric shock                        8
# Loss of sight                         7
# Open wound                            5
# Poisoning or Toxic effects            5
# Hearing Loss (work related)           4
# Exposure to infectious material       3
# Dislocation                           3
# Foreign Body                          3
# Poisoning or Toxic Effects            1
# Name: Injury, dtype: int64

# %%
# Percentage of missing vlaues per columns

missing_percentages_demo = demographic_df.isna().sum().sort_values(ascending = False)/len(demographic_df)
missing_percentages_demo
# Out:
# Employee Name     0.0
# Gender            0.0
# Relationship      0.0
# Position Title    0.0
# Age Band          0.0
# Ethnicity         0.0
# Salary Range      0.0
# dtype: float64

# %%
missing_percentages_event = event_df.isna().sum().sort_values(ascending = False)/len(event_df)
missing_percentages_event
# Out:
# Site 3 Name                      0.213914
# Site 2 Name                      0.024057
# Incident ID                      0.000000
# Incident Date                    0.000000
# Site 1 Name                      0.000000
# Incident Work Area Name          0.000000
# Event Type Name                  0.000000
# Person Employee Name             0.000000
# Incident Categories Full Name    0.000000
# Potential Consequence            0.000000
# Action Taken                     0.000000
# dtype: float64

# %%
missing_percentages_injury = injury_df.isna().sum().sort_values(ascending = False)/len(injury_df)
missing_percentages_injury
# Out:
# Injury                 0.196030
# Body Part              0.047457
# Sub Category           0.000931
# Incident ID            0.000000
# Name                   0.000000
# Treatment of Injury    0.000000
# Incident Status        0.000000
# Investigation Type     0.000000
# dtype: float64

# %%
missing_injury =injury_df.isna().sum()
missing_injury
# Out:
# Incident ID              0
# Injury                 632
# Name                     0
# Sub Category             3
# Body Part              153
# Treatment of Injury      0
# Incident Status          0
# Investigation Type       0
# dtype: int64

# %%
missing_percentages_injury[missing_percentages_injury != 0].plot(kind = 'barh')
# Out:
# <AxesSubplot: >

# %%
missing_percentages_event[missing_percentages_event != 0].plot(kind = 'barh')
# Out:
# <AxesSubplot: >

# %%
#Check for duplication

duplicates_demo = demographic_df.duplicated()

duplicates_demo.describe()
# Out:
# count      1621
# unique        1
# top       False
# freq       1621
# dtype: object

# %%
duplicates_event = event_df.duplicated()

duplicates_event.describe()
# Out:
# count      3076
# unique        1
# top       False
# freq       3076
# dtype: object

# %%
duplicates_injury = injury_df.duplicated()

duplicates_injury.describe()
# Out:
# count      3224
# unique        2
# top       False
# freq       2764
# dtype: object

# %%
print(injury_df[duplicates_injury])
# Out:
#       Incident ID                  Injury       Name  \
# 27             71          Sprain /Strain  Ergonomic
# 49            172   Loss of consciousness   Physical
# 52            208          Puncture wound   Violence
# 64            258  Psychological distress   Violence
# 65            258  Psychological distress   Violence
# ...           ...                     ...        ...
# 3219         2451          Sprain /Strain  Ergonomic
# 3220         2452           Bone Fracture   Physical
# 3221         2454           Scald or burn   Physical
# 3222         2456          Sprain /Strain  Ergonomic
# 3223         2457          Sprain /Strain  Ergonomic
#
#                                  Sub Category  Body Part  \
# 27                               Keyboard use      Wrist
# 49    Trip / fall hazard (cords /chairs etc.)        NaN
# 52                            Use of a weapon       Hand
# 64                                    Threats        NaN
# ...

# %%
#This shows that we have a few duplicates that we need to delete from the dataframe

# %%
#Cleaning the data

# %%
injury_df = injury_df.drop_duplicates()
injury_df
# Out:
#       Incident ID                 Injury       Name  \
# 0               5         Sprain /Strain  Ergonomic
# 1               9         Sprain /Strain  Ergonomic
# 2              11         Sprain /Strain  Ergonomic
# 3              12         Sprain /Strain   Physical
# 4              16         Sprain /Strain   Physical
# ...           ...                    ...        ...
# 3071        10987                    NaN  Ergonomic
# 3072        10990  Loss of consciousness   Physical
# 3073        10998                    NaN  Ergonomic
# 3074        11001             Unassigned  Ergonomic
# 3075        11003         Sprain /Strain  Ergonomic
#
#                                  Sub Category           Body Part  \
# 0                    Lifting / carrying loads           Shoulders
# 1                           Poor work posture                Back
# 2                                Keyboard use               Wrist
# 3     Trip / fall hazard (cords /chairs etc.)               Ankle
# ...

# %%
missing_injury =injury_df.isna().sum()
missing_injury
# Out:
# Incident ID              0
# Injury                 570
# Name                     0
# Sub Category             3
# Body Part              123
# Treatment of Injury      0
# Incident Status          0
# Investigation Type       0
# dtype: int64

# %%
injury_df = injury_df.dropna(subset=['Injury'])
injury_df
# Out:
#       Incident ID                 Injury       Name  \
# 0               5         Sprain /Strain  Ergonomic
# 1               9         Sprain /Strain  Ergonomic
# 2              11         Sprain /Strain  Ergonomic
# 3              12         Sprain /Strain   Physical
# 4              16         Sprain /Strain   Physical
# ...           ...                    ...        ...
# 3069        10980         Sprain /Strain  Ergonomic
# 3070        10985             Unassigned   Violence
# 3072        10990  Loss of consciousness   Physical
# 3074        11001             Unassigned  Ergonomic
# 3075        11003         Sprain /Strain  Ergonomic
#
#                                  Sub Category          Body Part  \
# 0                    Lifting / carrying loads          Shoulders
# 1                           Poor work posture               Back
# 2                                Keyboard use              Wrist
# 3     Trip / fall hazard (cords /chairs etc.)              Ankle
# ...

# %%
injury_df = injury_df.drop(index=injury_df[injury_df['Injury'] == 'Unassigned'].index)
injury_df
# Out:
#       Incident ID                 Injury       Name  \
# 0               5         Sprain /Strain  Ergonomic
# 1               9         Sprain /Strain  Ergonomic
# 2              11         Sprain /Strain  Ergonomic
# 3              12         Sprain /Strain   Physical
# 4              16         Sprain /Strain   Physical
# ...           ...                    ...        ...
# 3063        10952         Sprain /Strain  Ergonomic
# 3068        10963         Sprain /Strain   Physical
# 3069        10980         Sprain /Strain  Ergonomic
# 3072        10990  Loss of consciousness   Physical
# 3075        11003         Sprain /Strain  Ergonomic
#
#                                  Sub Category          Body Part  \
# 0                    Lifting / carrying loads          Shoulders
# 1                           Poor work posture               Back
# 2                                Keyboard use              Wrist
# 3     Trip / fall hazard (cords /chairs etc.)              Ankle
# ...

# %%
# Convert the Incident Date column to datetime and derived new columns year, month and day from it.

event_df['Incident Date'] = pd.to_datetime(event_df['Incident Date'], format='%d/%m/%Y')
event_df['year'] = event_df['Incident Date'].dt.year
event_df['month'] = event_df['Incident Date'].dt.month
event_df['day'] = event_df['Incident Date'].dt.day

event_df.info()
print(event_df['Incident Date'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3076 entries, 0 to 3075
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Incident ID                    3076 non-null   int64
#  1   Incident Date                  3076 non-null   datetime64[ns]
#  2   Site 1 Name                    3076 non-null   object
#  3   Site 2 Name                    3002 non-null   object
#  4   Site 3 Name                    2418 non-null   object
#  5   Incident Work Area Name        3076 non-null   object
#  6   Event Type Name                3076 non-null   object
#  7   Person Employee Name           3076 non-null   object
#  8   Incident Categories Full Name  3076 non-null   object
#  9   Potential Consequence          3076 non-null   object
#  10  Action Taken                   3076 non-null   object
#  11  year                           3076 non-null   int64
# ...

# %%
#Now that we've cleansed the data we can start analysing the data.

# %%
#Distribution of demographics by gender

gender_counts = demographic_df["Gender"].value_counts()
plt.bar(gender_counts.index, gender_counts.values)
plt.title("Distribution of demographics by Gender")
plt.xlabel("Gender")
plt.ylabel("Number of Employees")
plt.show()

# %%
#Distribution of demographics by ethnicity

ethnicity_counts = demographic_df["Ethnicity"].value_counts()
plt.bar(ethnicity_counts.index, ethnicity_counts.values)
plt.title("Distribution of demographics by Ethnicity")
plt.xlabel("Ethnicity")
plt.ylabel("Number of Employees")
plt.show()

# %%
#Distribution of demographics by Age Band

age_counts = demographic_df["Age Band"].value_counts()
plt.bar(age_counts.index, age_counts.values)
plt.title("Distribution of demographics by Age Band")
plt.xlabel("Age Band")
plt.ylabel("Number of Employees")
plt.show()

# %%
#Distribution of demographics by Salary Range

sal_counts = demographic_df["Salary Range"].value_counts()
plt.bar(sal_counts.index, sal_counts.values)
plt.title("Distribution of demographics by Salary Range")
plt.xlabel("Salary Range")
plt.ylabel("Number of Employees")
plt.show()

# %%
#Regions with the highest incident and lowest incident rates

#To achieve this we need to mmerge the data frames to get the information we need. 

#We need to update the column name of 'Person Employee Name' to 'Employee Name in the events df to match the column name in demographics df

event_df = event_df.rename(columns={'Person Employee Name': 'Employee Name'})
event_df.head()
# Out:
#    Incident ID Incident Date              Site 1 Name Site 2 Name Site 3 Name  \
# 0            5    2019-05-20  Client Service Delivery    Region P       Lo_19
# 1            9    2019-05-21  Client Service Delivery    Region H        Ch_4
# 2           11    2019-05-22  Client Service Delivery    Region L       Du_14
# 3           12    2019-05-23  Client Service Delivery    Region H        Ch_4
# 4           16    2019-05-28  Client Service Delivery    Region L       Du_14
#
#       Incident Work Area Name     Event Type Name Employee Name  \
# 0    Staff only area (zone 3)  Accident or Injury    Person 999
# 1    Staff only area (zone 3)  Pain or Discomfort    Person 998
# 2  Interviewing area (zone 2)  Pain or Discomfort    Person 997
# 3    Staff only area (zone 3)  Accident or Injury    Person 995
# 4                Seminar room  Accident or Injury    Person 994
#
#   Incident Categories Full Name Potential Consequence  \
# ...

# %%
# merge the injury and event dataframes on the Incident ID column

injury_event_df = pd.merge(injury_df, event_df, on='Incident ID')
injury_event_df.head()
# Out:
#    Incident ID          Injury       Name  \
# 0            5  Sprain /Strain  Ergonomic
# 1            9  Sprain /Strain  Ergonomic
# 2           11  Sprain /Strain  Ergonomic
# 3           12  Sprain /Strain   Physical
# 4           16  Sprain /Strain   Physical
#
#                               Sub Category          Body Part  \
# 0                 Lifting / carrying loads          Shoulders
# 1                        Poor work posture               Back
# 2                             Keyboard use              Wrist
# 3  Trip / fall hazard (cords /chairs etc.)              Ankle
# 4                 Moving or falling object  Finger(s) / Thumb
#
#                            Treatment of Injury Incident Status  \
# 0     1. First aid injury or muscle discomfort          Closed
# 1                              0. No Treatment          Closed
# 2     1. First aid injury or muscle discomfort          Closed
# 3     1. First aid injury or muscle discomfort          Closed
# ...

# %%
# merge the injury_event and demographic dataframes on the Employee Name column

final_df = pd.merge(injury_event_df, demographic_df, on='Employee Name')
final_df.head()
# Out:
#    Incident ID               Injury       Name              Sub Category  \
# 0            5       Sprain /Strain  Ergonomic  Lifting / carrying loads
# 1         6730       Sprain /Strain  Ergonomic         Workstation setup
# 2         7873  Bruising / Crushing   Physical  Moving or falling object
# 3            9       Sprain /Strain  Ergonomic         Poor work posture
# 4           11       Sprain /Strain  Ergonomic              Keyboard use
#
#    Body Part                       Treatment of Injury Incident Status  \
# 0  Shoulders  1. First aid injury or muscle discomfort          Closed
# 1       Hand  1. First aid injury or muscle discomfort          Closed
# 2      Wrist  1. First aid injury or muscle discomfort          Closed
# 3       Back                           0. No Treatment          Closed
# 4      Wrist  1. First aid injury or muscle discomfort          Closed
#
#      Investigation Type Incident Date              Site 1 Name  ...  \
# ...

# %%
# rate = number of incidents per employee
# calculate incident rates by region

incident_rates_by_region = final_df.groupby('Site 2 Name')['Incident ID'].count() / final_df.groupby('Site 2 Name')['Employee Name'].nunique()

# sort regions by incident rates in descending order

sorted_regions = incident_rates_by_region.sort_values(ascending=False)

# %%
# create a bar chart of incident rates by region

plt.bar(sorted_regions.index, sorted_regions.values)
plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Incident Rate')
plt.title('Regions with highest and lowest incident rates')
plt.show()

# %%
# total incidents by region
incidents_by_region = final_df.groupby("Site 2 Name")["Incident ID"].count()

# sort by count in descending order

incidents_by_region = incidents_by_region.sort_values(ascending=False)

# plot the results

incidents_by_region.plot(kind="bar", figsize=(10, 6))
plt.title("Total Incidents by Region")
plt.xlabel("Region")
plt.ylabel("Total Incidents")
plt.show()

# %%
# Summary on the top 5 type of incidents

# get the top 5 incident types

top_incidents = final_df["Injury"].value_counts().head(5)

# plot the results

top_incidents.plot(kind="bar", figsize=(10, 6))
plt.title("Top 5 Incident Types")
plt.xlabel("Incident Type")
plt.ylabel("Total Incidents")
plt.show()

# %%
# Top 5 common body parts injured

# get the top 5 injured body parts

top_body_parts = final_df["Body Part"].value_counts().head(5)

# plot the results

top_body_parts.plot(kind="bar", figsize=(10, 6))
plt.title("Top 5 Injured Body Parts")
plt.xlabel("Body Part")
plt.ylabel("Total Injuries")
plt.show()

# %%
# Top 5 Position Titles with most injuries

# Group by Position Type and count the number of injuries

position_counts = final_df.groupby('Position Title')['Injury'].count()

# Sort in descending order and get the top 5 positions

top_5_positions = position_counts.sort_values(ascending=False).head(5)

# Plot a bar chart of the top 5 positions
plt.bar(top_5_positions.index, top_5_positions.values)
plt.title('Top 5 Position Types with the Most Injuries')
plt.xlabel('Position Type')
plt.xticks(rotation=90)
plt.ylabel('Number of Injuries')
plt.show()

# %%
# calculate injury count by salary range

# Count the number of injury incidents by salary range

injury_count_by_salary = final_df.groupby('Salary Range')['Injury'].count().reset_index()

# Sort the values by count in descending order

injury_count_by_salary = injury_count_by_salary.sort_values(by='Injury', ascending=False)

# Create a bar plot

plt.bar(injury_count_by_salary['Salary Range'], injury_count_by_salary['Injury'])
plt.xlabel('Salary Range')
plt.ylabel('Number of Injury Incidents')
plt.title('Number of Injury Incidents by Salary Range')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
# Finding the timeline of the dataset

# Fetching Earliest date and Latest date from the data set

earliest_date = final_df['Incident Date'].min()
latest_date = final_df['Incident Date'].max()

print('Earliest date:', earliest_date)
print('Latest date:', latest_date)
# Out:
# Earliest date: 2018-02-10 00:00:00
# Latest date: 2021-01-19 00:00:00

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2388 entries, 0 to 2387
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Incident ID                    2388 non-null   int64
#  1   Injury                         2388 non-null   object
#  2   Name                           2388 non-null   object
#  3   Sub Category                   2386 non-null   object
#  4   Body Part                      2341 non-null   object
#  5   Treatment of Injury            2388 non-null   object
#  6   Incident Status                2388 non-null   object
#  7   Investigation Type             2388 non-null   object
#  8   Incident Date                  2388 non-null   datetime64[ns]
#  9   Site 1 Name                    2388 non-null   object
#  10  Site 2 Name                    2332 non-null   object
#  11  Site 3 Name                    1874 non-null   object
# ...

# %%
# plotting the frequency of incidents

final_df['date'] = pd.to_datetime(final_df['Incident Date'])

final_df.set_index('date', inplace=True)

# Resample the data by week and count the number of incidents per week
weekly_counts = final_df.resample('W')['Incident ID'].count()

# Plot the time series
weekly_counts.plot()
plt.xlabel('Week')
plt.ylabel('Number of incidents')
plt.title('Timeline of incidents')
plt.show()

# %%
# Monthly frequency

# Resample the data by month and count the number of incidents per month
monthly_counts = final_df.resample('M')['Incident ID'].count()

# Plot the time series
monthly_counts.plot()
plt.xlabel('Month')
plt.ylabel('Number of incidents')
plt.title('Timeline of incidents')
plt.show()

# %%
# Plotting the locations of injuries

# create a new dataframe with injury counts by site

injury_by_site = final_df['Site 1 Name'].value_counts()

# plot the distribution of injuries by site
plt.figure(figsize=(8,6))
sns.barplot(x=injury_by_site.index, y=injury_by_site.values)
plt.title('Injury Distribution by Site')
plt.xlabel('Site Name')
plt.ylabel('Injury Count')
plt.xticks(rotation=90)
plt.show()

# %%
final_df['Site 1 Name'].unique()
# Out:
# array(['Client Service Delivery', 'National Office', 'Offsite'],
#       dtype=object)

# %%
# type of events captured at sites


# filter for a specific site name
site_name = "Client Service Delivery"
site_df = final_df[final_df["Site 1 Name"] == site_name]

# check if site_df is empty before proceeding
if site_df.empty:
    print("No data available for site:", site_name)
else:
    # group by injury type and get the count of each type of injury
    injury_counts = site_df.groupby("Event Type Name")["Incident ID"].count().sort_values(ascending=False)

    # plot the results as a bar chart
    injury_counts.plot(kind="bar")
    plt.title("Types of Injuries at {}".format(site_name))
    plt.xlabel("Injury Type")
    plt.ylabel("Count")
    plt.show()

# %%
# Visualising the incident status

# group by incident status and get the count of each status

incident_status_counts = final_df.groupby("Incident Status")["Incident ID"].count()

# create a bar to show the distribution of incident statuses

incident_status_counts.plot(kind="bar")
plt.title("Distribution of Incident Statuses")
plt.xlabel("Incident Statuses")
plt.ylabel("Number of Cases")
plt.show()

# %%
# Visualising the Potential consequences of the incidents

# group by Potential consequences and get the count of each consequences

potential_consequence_counts = final_df.groupby("Potential Consequence")["Incident ID"].count()

# create a bar to show the distribution of Potential Consequence

potential_consequence_counts.plot(kind="bar")
plt.title("Distribution of Potential Consequence")
plt.xlabel("Potential Consequences")
plt.ylabel("Number of Cases")
plt.show()

# %%
# Visualising the Treatments of Injuries

# group by Treatments of Injuries and get the count of each treatment

potential_consequence_counts = final_df.groupby("Treatment of Injury")["Incident ID"].count()

# create a bar to show the distribution of incident statuses

potential_consequence_counts.plot(kind="bar")
plt.title("Distribution of Treatment of Injury")
plt.xlabel("Treatments")
plt.ylabel("Number of Cases")
plt.show()

# %%
# Visualising the Nature of Injuries

# group by Nature of Injuries and get the count of each Nature

injury_nature_counts = final_df.groupby("Name")["Incident ID"].count()

# create a bar to show the distribution of incident statuses

injury_nature_counts.plot(kind="bar")
plt.title("Distribution of Nature of Injury")
plt.xlabel("Names")
plt.ylabel("Number of Cases")
plt.show()

# %%
# Visualising the Ergonimic Nature of Injuries

# group by Nature of Injuries and get the count of each Nature for Ergonomic type of injuries  

ergonomic_df = final_df[final_df["Name"] == "Ergonomic"]

subcategory_counts = ergonomic_df.groupby("Sub Category")["Incident ID"].count().sort_values(ascending=False)


# create a bar to show the distribution of incident statuses

subcategory_counts.plot(kind="bar")
plt.title("Distribution of Nature of Injury for Ergonomic Type")
plt.xlabel("Sub Category")
plt.ylabel("Number of Incidents")
plt.show()

# %%
# Downloading the merged data

final_df.to_csv('Final_data.csv', index=False)

# %%
# Report for the analysis in 'EDA - MSD Report.doc'
